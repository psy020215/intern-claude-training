# %% [markdown]
# # **Claude Code Training — Module 2:** <a name="module-2"></a>

# %% [markdown]
# **Contents:**
# **Question 1: ([Go link](#issue-2_1))**
# **Question 2: ([Go link](#issue-2_2))**
# **Question 3: ([Go link](#issue-2_3))**
# **Question 4: ([Go link](#issue-2_4))**

# %% [markdown]
# ### **# Question 2-1** <a name="issue-2_1"></a>
#
# The GFF format is the standard file format for genome annotations in this lab. Use Claude Code to understand its structure and how to load it correctly with pandas.
#
# * Checklist:
#   * **Use Claude Code to generate the correct pandas code to load a GFF file. Paste the code in the code cell.**
#   * **In the answer sheet: what happens if you omit `header=None`? Write one sentence.**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```

# %% [markdown]
# ### **# Question 2-2** <a name="issue-2_2"></a>
# Claude Code can turn a plain-English description of a task directly into a working script. The workflow is:
#
# 1. **Describe the task in plain English** — be specific about the file format, the columns involved, and the expected output.
# 2. **Claude Code generates a first draft.** Your first prompt is a draft, not a final answer.
# 3. **Refine with follow-up prompts.** Fix edge cases, add output formatting, handle errors, change the logic. Most production scripts go through 3–10 iterations before they are committed.
#
# Tips for better first prompts:
# - Name the file format explicitly: *"a GFF file"*, not *"a text file"*.
# - State the output: *"print the result to stdout"* or *"save to a new TSV file"*.
# - Mention edge cases: *"skip comment lines"*, *"ignore rows where score is `.`"*.
#
# * Checklist:
#   * **Describe a GFF filtering task in plain English to Claude Code. Generate the script. Refine it with at least two follow-up prompts. Paste the final script in the code cell.**
#   * **In the answer sheet: write what changed between your first and final version. What did the follow-up prompts fix or improve?**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```

# %% [markdown]
# ### **# Question 2-3** <a name="issue-2_3"></a>
# The script below has **two bugs**. Read it carefully, then use Claude Code (or `/debug` if needed) to diagnose and fix them.
#
# ```python
# import pandas as pd
# df = pd.read_csv('example.gff', sep='\t')
# forward = df[df['strand'] == '+']
# fifth = forward.iat[5]
# print(f"5th forward feature starts at position {fifth['start']}")
# ```
#
# There are two bugs. Use `/debug` if needed.
#
# * Checklist:
#   * **Run the script and observe both errors. Fix the script using Claude Code. Paste the fixed version in the code cell.**
#   * **In the answer sheet: name both bugs and their root causes in one sentence each.**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```

# %% [markdown]
# ### **# Question 2-4** <a name="issue-2_4"></a>
#
# `iterrows()` iterates over a DataFrame row by row. Use Claude Code to understand when it is appropriate and when it should be avoided.
#
# * Checklist:
#   * **Use Claude Code to understand when `iterrows()` is appropriate and when to avoid it.**
#   * **In the answer sheet: write two sentences — when should you use it? When should you avoid it, and what should you use instead?**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```
