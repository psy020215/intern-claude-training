# %% [markdown]
# # Mini-Project: [Your Title Here]
# **Intern:** [Your name]
# **Date started:** [Start date]
# **Dataset:** [Describe the dataset — organism, experiment type, one sentence]

# %% [markdown]
# ---
# ## Schedule Overview
#
# | Day | Target milestone |
# |-----|------------------|
# | W5 D1 | Dataset explored; files listed, formats understood |
# | W5 D2 | Literature context written; biological question drafted |
# | W5 D3 | Biological question finalized; analysis plan approved by instructor |
# | W5 D4–5 | Pipeline running; first results visible |
# | W6 D1–3 | All pipeline steps done; figures generated |
# | W6 D4–5 | Report written; notebook submitted |
#
# Run `/log` at the end of **every day** — no exceptions. Your log is your progress record.

# %% [markdown]
# ---
# ## Part 1 — Dataset Exploration
# **Target: W5 Day 1**
#
# > **Reference data:** The lab *E. coli* K-12 annotation GFF (with TSS positions) is at
# > `../data/reference/ec_annotation_20100903_DHK_cSRNA_with_ortho.gff`
# > Use it for TSS distance analysis if your project involves *E. coli* K-12 binding sites.
#
# Use Claude Code to explore the dataset. List all files, check sizes, identify formats.

# %%
# %%bash
# # Explore the data/ directory — list files, sizes, first few lines of each

# %% [markdown]
# **Dataset summary** — describe what files you found, formats, organism, and experiment type:

# %% [markdown]
# [Your dataset summary here]

# %% [markdown]
# > **W5 D1 checkpoint:** Before ending today, confirm:
# > - [ ] All files in `data/reference/` listed with formats identified
# > - [ ] Organism and experiment type understood
# > - [ ] `/log` run

# %% [markdown]
# ---
# ## Part 2 — Literature Context
# **Target: W5 Day 2**
#
# Use Claude to find what is already known about the gene, regulator, or condition in this dataset.
# Extract any reference gene lists or coordinates from relevant papers.

# %% [markdown]
# **What is known** — 3–5 sentences summarizing the literature context. Cite papers:

# %% [markdown]
# [Your literature summary here]

# %% [markdown]
# **Reference data from literature** — if you extracted gene lists or coordinates, describe what you got and how you validated it against the original source:

# %%
# Paste extracted reference data here (gene lists, coordinates, known targets, etc.)

# %% [markdown]
# ---
# ## Part 3 — Biological Question
# **Target: W5 Day 2–3**
#
# Propose **one specific, answerable** question based on your dataset and literature context.
#
# A good question names: the specific genes/regulator, the comparison or condition, and a measurable threshold or outcome.
# Examples of acceptable specificity:
# - *"Which sRNA genes show >2-fold upregulation in ΔrpoS vs WT at OD 0.6?"*
# - *"Do the 143 FUR ChIP-exo peaks in Seo et al. 2014 cluster near annotated TSS positions?"*
#
# **Not acceptable:** *"What happens to gene expression?"*

# %% [markdown]
# **My biological question:**

# %% [markdown]
# [Your biological question here]

# %% [markdown]
# > **INSTRUCTOR CHECK-IN REQUIRED** before proceeding to Part 4.
# > Show your question to the instructor. Do not start the analysis plan until approved.

# %% [markdown]
# ---
# ## Part 4 — Analysis Plan
# **Target: W5 Day 3**
#
# Write your analysis plan in plain English **before** opening Claude Code. This is your own thinking.
#
# Your plan must answer:
# 1. What input data will you use?
# 2. What steps will you run (in order)?
# 3. What output do you expect at each step?
# 4. How will you know if the result is biologically meaningful?

# %% [markdown]
# [Your analysis plan here — write this before asking Claude Code]

# %% [markdown]
# **Pipeline scaffold** — once your plan is written, use plan mode (Shift+Tab) to generate the pipeline.
# Review **every proposed step**. Annotate each command with your own understanding of what it does.

# %%
# Pipeline scaffold — generated with plan mode, annotated by you
# Do NOT run this until you have reviewed and annotated every line

# %% [markdown]
# > **W5 D3 checkpoint:** Before ending today:
# > - [ ] Analysis plan written in your own words
# > - [ ] Pipeline scaffold annotated (you can explain every command)
# > - [ ] Instructor has approved your biological question
# > - [ ] `/log` run

# %% [markdown]
# ---
# ## Part 5 — Analysis Execution
# **Target: W5 Days 4–5 and W6 Days 1–3**
#
# Run your pipeline step by step. Add code cells as needed.
# When blocked: paste the error + command + relevant output into Claude Code and ask for diagnosis — then use `/debug`.
#
# Track your progress below:
#
# | Step | Status |
# |------|--------|
# | [Step 1 name] | not started / in progress / done |
# | [Step 2 name] | not started / in progress / done |
# | [Step 3 name] | not started / in progress / done |
#
# (Edit this table as you work.)

# %%
# Step 1

# %% [markdown]
# *What did this step produce? Any issues?*

# %%
# Step 2

# %% [markdown]
# *What did this step produce? Any issues?*

# %%
# Step 3

# %% [markdown]
# *What did this step produce? Any issues?*

# %% [markdown]
# *(Add more step cells as needed.)*

# %% [markdown]
# > **W5 D5 checkpoint:** Before ending Week 5:
# > - [ ] At least first 2 pipeline steps producing output
# > - [ ] Any blockers documented in `/log`
# > - [ ] `/log` run

# %% [markdown]
# ---
# ## Part 6 — Results
# **Target: W6 Days 1–3**
#
# Document your results. Include figures. Each figure needs a 1–2 sentence caption describing what it shows — not just what was plotted, but what you observe.

# %%
# Figure 1

# %% [markdown]
# **Figure 1:** [Describe what this figure shows and what you observe]

# %%
# Figure 2 (add as needed)

# %% [markdown]
# **Figure 2:** [Caption]

# %% [markdown]
# > **W6 D3 checkpoint:**
# > - [ ] All pipeline steps complete and results saved
# > - [ ] At least one figure generated with a written caption
# > - [ ] `/log` run

# %% [markdown]
# ---
# ## Part 7 — Report
# **Target: W6 Days 4–5**
#
# Write your analysis report in the cells below. This is **your own writing** — Claude Code may be consulted for phrasing, but the scientific content must be yours.

# %% [markdown]
# ### Question
# *(one sentence)*

# %% [markdown]
# [Your question here]

# %% [markdown]
# ### Methods
# *(describe tools, parameters, datasets — enough that someone could reproduce this)*

# %% [markdown]
# [Your methods here]

# %% [markdown]
# ### Results
# *(what did you find? reference your figures by number)*

# %% [markdown]
# [Your results here]

# %% [markdown]
# ### Interpretation
# *(what does this mean biologically? How does it compare to what was known from the literature?)*

# %% [markdown]
# [Your interpretation here]

# %% [markdown]
# ### Limitations
# *(what would you do differently with more time or data?)*

# %% [markdown]
# [Your limitations here]

# %% [markdown]
# ---
# **Final submission:** Run `/log` one last time, then submit this notebook as your deliverable.
